-- %%
ALTER TABLE CMNS_BAIRRO
  ADD  BAIR_CODIGO CODE_010;

ALTER TABLE CMNS_GRUPO_USUARIO
    ADD GRUS_CODIGO CODE_010;

ALTER TABLE CMNS_LOCALIDADE
    ADD LCLD_CODIGO CODE_010;

ALTER TABLE CMNS_LOGRADOURO 
    ADD LGRD_CODIGO CODE_010;

ALTER TABLE CMNS_PAIS
    ADD PAIS_CODIGO  CODE_005;

ALTER TABLE CMNS_UNIDADE_FEDERATIVA
    ADD UNFD_CODIGO CODE_010;

ALTER TABLE CMNS_USUARIO
    ADD USRS_CODIGO CODE_010 NOT NULL;    

ALTER TABLE MENU_MODULO
    ADD MODL_CODIGO CODE_005;

ALTER TABLE MENU_PASTA
    ADD PSTA_CODIGO CODE_010;

ALTER TABLE MENU_RECURSO
    ADD RCRS_CODIGO CODE_015;
-- Out:
-- : Msg 2705, Level 16, State 4, Line 1
-- Os nomes de colunas em cada tabela devem ser exclusivos. O nome da coluna 'BAIR_CODIGO' na tabela 'CMNS_BAIRRO' foi especificado mais de uma vez.
-- Total execution time: 00:00:00.017

-- %%
ALTER TABLE MENU_MODULO
    ADD MODL_CODIGO CODE_005;

ALTER TABLE MENU_PASTA
    ADD PSTA_CODIGO CODE_010;

ALTER TABLE MENU_RECURSO
    ADD RCRS_CODIGO CODE_015;
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.036
